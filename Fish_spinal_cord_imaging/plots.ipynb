# %%
from bil.m import rigS
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import h5py
from pathlib import Path
from scipy.optimize import curve_fit
from scipy import stats

# %% [markdown]
# # zstd

# %%
runID_list = ['double_fish_1_before','double_fish_1_after',
              'double_fish_2_before','double_fish_2_after',
              'double_fish_3_before','double_fish_3_after',
              'single_cutA_before','single_cutA_after',
              'single_cutM_before','single_cutM_after',
              'single_cutP_before','single_cutP_after']
all_data=[np.load(runID+"_compression_rate_zstd.npy") for runID in runID_list]

import matplotlib.pyplot as plt
import numpy as np

categories = ['fish_1', 'fish_2', 'fish_3','fish_4','fish_5','fish_6']
group1_values = all_data[0::2]
group2_values = all_data[1::2]

bar_width = 0.35

bar_positions_group1 = np.arange(len(categories))
bar_positions_group2 = bar_positions_group1 + bar_width

plt.bar(bar_positions_group1, group1_values, width=bar_width, label='pre-ablation')
plt.bar(bar_positions_group2, group2_values, width=bar_width, label='post-ablation')

plt.xlabel('subjects')
plt.ylabel('ICR')
plt.title('ZSTD Lossless Compression')

plt.xticks(bar_positions_group1 + bar_width / 2, categories)

plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# # gzip

# %%
runID_list = ['double_fish_1_before','double_fish_1_after',
              'double_fish_2_before','double_fish_2_after',
              'double_fish_3_before','double_fish_3_after',
              'single_cutA_before','single_cutA_after',
              'single_cutM_before','single_cutM_after',
              'single_cutP_before','single_cutP_after']
all_data=[np.load(runID+"_compression_rate_gzip.npy") for runID in runID_list]

import matplotlib.pyplot as plt
import numpy as np

categories = ['fish_1', 'fish_2', 'fish_3','fish_4','fish_5','fish_6']
group1_values = all_data[0::2]
group2_values = all_data[1::2]

bar_width = 0.35

bar_positions_group1 = np.arange(len(categories))
bar_positions_group2 = bar_positions_group1 + bar_width

plt.bar(bar_positions_group1, group1_values, width=bar_width, label='pre-ablation')
plt.bar(bar_positions_group2, group2_values, width=bar_width, label='post-ablation')

plt.xlabel('subjects')
plt.ylabel('ICR')
plt.title('GZIP Lossless Compression')

plt.xticks(bar_positions_group1 + bar_width / 2, categories)

plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ## h264

# %%
runID_list = ['double_fish_1_before','double_fish_1_after',
              'double_fish_2_before','double_fish_2_after',
              'double_fish_3_before','double_fish_3_after',
              'single_cutA_before','single_cutA_after',
              'single_cutM_before','single_cutM_after',
              'single_cutP_before','single_cutP_after']
all_data=[np.load(runID+"_compression_rate_h264.npy") for runID in runID_list]

import matplotlib.pyplot as plt
import numpy as np

categories = ['fish_1', 'fish_2', 'fish_3','fish_4','fish_5','fish_6']
group1_values = all_data[0::2]
group2_values = all_data[1::2]

bar_width = 0.35

bar_positions_group1 = np.arange(len(categories))
bar_positions_group2 = bar_positions_group1 + bar_width

plt.bar(bar_positions_group1, group1_values, width=bar_width, label='pre-ablation')
plt.bar(bar_positions_group2, group2_values, width=bar_width, label='post-ablation')

plt.xlabel('subjects')
plt.ylabel('ICR')
plt.title('H264 Lossy Compression')

plt.xticks(bar_positions_group1 + bar_width / 2, categories)

plt.legend(loc='upper right')

plt.show()

# %%
runID_list = ['double_fish_1_before','double_fish_1_after',
              'double_fish_2_before','double_fish_2_after',
              'double_fish_3_before','double_fish_3_after',
              'single_cutA_before','single_cutA_after',
              'single_cutM_before','single_cutM_after',
              'single_cutP_before','single_cutP_after']
all_data=[np.load(runID+"_compression_rate_h264_n.npy") for runID in runID_list]

import matplotlib.pyplot as plt
import numpy as np

categories = ['fish_1', 'fish_2', 'fish_3','fish_4','fish_5','fish_6']
group1_values = all_data[0::2]
group2_values = all_data[1::2]

bar_width = 0.35

bar_positions_group1 = np.arange(len(categories))
bar_positions_group2 = bar_positions_group1 + bar_width

plt.bar(bar_positions_group1, group1_values, width=bar_width, label='pre-ablation')
plt.bar(bar_positions_group2, group2_values, width=bar_width, label='post-ablation')

plt.xlabel('subjects')
plt.ylabel('ICR')
plt.title('H264 compressor (no position information)')

plt.xticks(bar_positions_group1 + bar_width / 2, categories)

plt.legend(loc='upper right')

plt.show()
